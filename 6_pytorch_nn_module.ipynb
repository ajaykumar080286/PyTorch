# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaykumar080286/PyTorch/blob/main/6_pytorch_nn_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
class Model(nn.Module):

  def __init__(self,num_feature):
    super().__init__()
    #decleare layer
    self.linear=nn.Linear(num_feature,1)
    #activation funcation
    self.sigmoid=nn.Sigmoid()

  def forward(self,feature):
    out=self.linear(feature)
    out=self.sigmoid(out)
    return out

# %%
# create dataset
features = torch.rand(10,5)
model=Model(features.shape[1])

# %%
model(features)
# Out:
# tensor([[0.5333],
#         [0.4935],
#         [0.5105],
#         [0.5512],
#         [0.4720],
#         [0.5167],
#         [0.5176],
#         [0.5968],
#         [0.5801],
#         [0.5195]], grad_fn=<SigmoidBackward0>)

# %%
model.linear.weight
# Out:
# Parameter containing:
# tensor([[ 0.2565, -0.4040, -0.1439, -0.3733,  0.0518]], requires_grad=True)

# %%
model.linear.bias
# Out:
# Parameter containing:
# tensor([0.4366], requires_grad=True)

# %%
# !pip install torchinfo

# %%
from torchinfo import summary

# %%
summary(model,input_size=(10,5))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# Model                                    [10, 1]                   --
# ├─Linear: 1-1                            [10, 1]                   6
# ├─Sigmoid: 1-2                           [10, 1]                   --
# ...
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.00
# ...
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ...
